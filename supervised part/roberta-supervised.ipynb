# %%
# !pip install numpy
# !pip install pandas

# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip list | grep -E 'transformers|tokenizers'
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-oure8sey
#   Running command git clone -q https://github.com/huggingface/transformers /tmp/pip-req-build-oure8sey
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 895 kB 14.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 64.1 MB/s
# ...
#      |████████████████████████████████| 56 kB 5.9 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 47.4 MB/s
# ...
#   Created wheel for transformers: filename=transformers-4.12.0.dev0-py3-none-any.whl size=2993841 sha256=4419f405dff1b5c6b09fa48e56fd50b1279bbc50a52df9816bb3ca2f1cb811bd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pevpbxxq/wheels/35/2e/a7/d819e3310040329f0f47e57c9e3e7a7338aa5e74c49acfe522
# Successfully built transformers
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
# ...

# %%
# !pip install torch
# !pip install scipy
# !pip install scikit-learn
# !pip install transformers
# !pip install seqeval
# !pip install tensorboardx

# %%
# !pip install ipykernel

# %%
# !pip install simpletransformers
# Out:
# ...
#      |████████████████████████████████| 231 kB 7.3 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 40.4 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 38.5 MB/s
# ...
#      |████████████████████████████████| 8.3 MB 40.6 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 37.1 MB/s
# ...
#      |████████████████████████████████| 290 kB 55.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 41.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 40.5 MB/s
# ...
#      |████████████████████████████████| 56 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 596 kB 42.1 MB/s
# ...
#      |████████████████████████████████| 180 kB 49.0 MB/s
# ...
#      |████████████████████████████████| 139 kB 54.4 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 34.6 MB/s
# ...
#      |████████████████████████████████| 243 kB 49.5 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

train = pd.read_csv('/content/drive/MyDrive/100mbout/berttrainfiqaheadline2.tsv', sep='\t', names=['No','text','labels'])
del train['No']
test = pd.read_csv('/content/drive/MyDrive/100mbout/arrangedallagree.csv' ,encoding="latin",header=None)#, names=['No','text','labels'])
test.columns = ["text",'labels']
#train = pd.read_csv('/content/berttrainfiqaheadline2.tsv', sep='\t', names=['No','text','labels'])
from simpletransformers.classification import MultiLabelClassificationModel
CUDA_LAUNCH_BLOCKING=1 
label_list = [-1,0,1] # 0,1,2
train.labels+=1
train = train[['text','labels']]
from simpletransformers.classification import ClassificationModel
from simpletransformers.model import TransformerModel

# Create a ClassificationModel
#model = ClassificationModel('roberta', '/content/roberta', num_labels=3)
#model = TransformerModel('roberta', 'roberta-base', num_labels=4, args={'learning_rate':1e-5, 'num_train_epochs': 2, 'reprocess_input_data': True, 'overwrite_output_dir': True})
#model = TransformerModel('roberta', '/content/roberta/', num_labels=3,args={'learning_rate':1e-5, 'num_train_epochs': 3, 'reprocess_input_data': True, 'overwrite_output_dir': True})
#model = MultiLabelClassificationModel('roberta', 'roberta-base', num_labels=6, args={'train_batch_size':2, 'gradient_accumulation_steps':16, 'learning_rate': 3e-5, 'num_train_epochs': 3, 'max_seq_length': 128})

# %%
test.labels+=1

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import seaborn as sns
import transformers
import json
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from transformers import RobertaModel, RobertaTokenizer
import logging
logging.basicConfig(level=logging.ERROR)
import torch
from tqdm.notebook import tqdm

from transformers import BertTokenizer
from torch.utils.data import TensorDataset

from transformers import BertForSequenceClassification
MAX_LEN = 512
EPOCHS = 1
LEARNING_RATE = 1e-05
#tokenizer = RobertaTokenizer.from_pretrained('/content/roberta', truncation=True)

# %%
# !pip install -qq transformers

# %%
# !pip uninstall tqdm

# %%
# !pip install tqdm==4.49.0

# %%
import transformers

from transformers import BertModel, BertTokenizer, AdamW, get_linear_schedule_with_warmup

import torch

import numpy as np

import pandas as pd

import seaborn as sns

from pylab import rcParams

import matplotlib.pyplot as plt

from matplotlib import rc

from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, classification_report

from collections import defaultdict

from textwrap import wrap

from torch import nn, optim

from torch.utils.data import Dataset, DataLoader

# %%
from simpletransformers.classification import ClassificationModel
from simpletransformers.model import TransformerModel
model_args = {
    "num_train_epochs": 10,
    "learning_rate": 1e-4,
}
# Create a ClassificationModel
model = ClassificationModel('roberta', '/content/drive/MyDrive/checkpoint-550-epoch-10', num_labels=3, args={'learning_rate':1e-5, 'num_train_epochs': 1, 'reprocess_input_data': True, 'overwrite_output_dir': True,"evaluate_during_training":True})#, args={'learning_rate':1e-5, 'num_train_epochs': 3, 'reprocess_input_data': True, 'overwrite_output_dir': True)
#model = TransformerModel('roberta', '/content/roberta', num_labels=3, args={'learning_rate':1e-5, 'num_train_epochs': 3, 'reprocess_input_data': True, 'overwrite_output_dir': True})
# Out:
# Some weights of the model checkpoint at /content/drive/MyDrive/checkpoint-550-epoch-10 were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model.train_model(train)#,overwrite_output_dir=True)
# Out:
# ...
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# (550, 0.0)

# %% [markdown]
# **berttrainfiqapost2**

# %%
test = pd.read_csv('/content/berttrainfiqapost2.tsv', sep='\t', names=['No','text','labels'])
del test['No']
test.labels +=1
test.head()
# Out:
#                                                 text  labels
# 0  Slowly adding some $FIO here but gotta be care...       2
# 1   $TRX http://stks.co/1KkK Long setup. MACD cross.       2
# 2  I am not optimistic about $amzn both fundement...       0
# 3  $GRPN might be selling off ahead of $P earning...       0
# 4  $IACI http://stks.co/tJU Looks good on the wee...       2

# %% [markdown]
# **berttrainfiqaheadline2**

# %%
test = pd.read_csv('/content/berttrainfiqaheadline2.tsv', sep='\t', names=['No','text','labels'])
del test['No']
test.labels +=1
test.head()

# %% [markdown]
# **arrangedall**

# %%
test = pd.read_csv('/content/arrangedallagree.csv' ,encoding="latin",header=None)#, names=['No','text','labels'])
test.columns = ["text",'labels']
test.labels +=1
test.head()

# %% [markdown]
# **arranged75**

# %%
test = pd.read_csv('/content/arranged75agree.csv' ,encoding="latin",header=None)#, names=['No','text','labels'])
test.columns = ["text",'labels']
test.labels +=1
test.head()

# %% [markdown]
# **arranged66**

# %%
test = pd.read_csv('/content/arranged66agree.csv' ,encoding="latin",header=None)#, names=['No','text','labels'])
test.columns = ["text",'labels']
test.labels +=1
test.head()
# Out:
#                                                 text  labels
# 0  According to Gran , the company has no plans t...       1
# 1  Technopolis plans to develop in stages an area...       1
# 2  With the new production plant the company woul...       2
# 3  According to the company 's updated strategy f...       2
# 4  For the last quarter of 2010 , Componenta 's n...       2

# %% [markdown]
# **arranged50**

# %%
test = pd.read_csv('/content/arranged50agree.csv' ,encoding="latin",header=None)#, names=['No','text','labels'])
test.columns = ["text",'labels']
#del val['No']
#val.head()

# %%
#val = val.drop(val.columns[0])
test.labels +=1
test.head()

# %%
result, model_outputs, wrong_preds = model.eval_model(test)
# Out:
# ...
# Running Evaluation:   0%|          | 0/283 [00:00<?, ?it/s]

# %%
from sklearn.metrics import f1_score, accuracy_score
eval_df = test

def f1_multiclass(labels, preds):
    return f1_score(labels, preds, average='micro')
    
result, model_outputs, wrong_predictions = model.eval_model(eval_df, f1=f1_multiclass, acc=accuracy_score)
# Out:
# ...
# Running Evaluation:   0%|          | 0/55 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:900: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)

# %%
model.eval_model
# Out:
# <bound method ClassificationModel.eval_model of <simpletransformers.classification.classification_model.ClassificationModel object at 0x7f4a92857890>>

# %%
result
# Out:
# {'acc': 0.6444954128440367,
#  'eval_loss': 0.8456396937370301,
#  'f1': 0.6444954128440367,
#  'mcc': 0.0}

# %%
# !pip install numpy
# !pip install pandas

# %%
# !pip install regex requests
# !git clone https://github.com/Data-Science-kosta/Long-texts-Sentiment-Analysis-RoBERTa

# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip list | grep -E 'transformers|tokenizers'

# %%
# !pip install torch
# !pip install scipy
# !pip install scikit-learn
# !pip install transformers
# !pip install seqeval
# !pip install tensorboardx

# %%
# !pip install ipykernel

# %%
# !pip install simpletransformers

# %%
import pandas as pd
#train = pd.read_csv('/content/arrangedallagree.csv' ,encoding="latin",header=None)#, names=['No','text','labels'])
#train.columns = ["text",'labels']

train = pd.read_csv('/content/berttrainfiqapost2.tsv', sep='\t', names=['No','text','labels'])
from simpletransformers.classification import MultiLabelClassificationModel
CUDA_LAUNCH_BLOCKING=1 
label_list = [-1,0,1] # 0,1,2
train.labels+=1
train = train[['text','labels']]
from simpletransformers.classification import ClassificationModel
from simpletransformers.model import TransformerModel

# Create a ClassificationModel
#model = ClassificationModel('roberta', '/content/roberta', num_labels=3)
#model = TransformerModel('roberta', 'roberta-base', num_labels=4, args={'learning_rate':1e-5, 'num_train_epochs': 2, 'reprocess_input_data': True, 'overwrite_output_dir': True})
#model = TransformerModel('roberta', '/content/roberta/', num_labels=3,args={'learning_rate':1e-5, 'num_train_epochs': 3, 'reprocess_input_data': True, 'overwrite_output_dir': True})
#model = MultiLabelClassificationModel('roberta', 'roberta-base', num_labels=6, args={'train_batch_size':2, 'gradient_accumulation_steps':16, 'learning_rate': 3e-5, 'num_train_epochs': 3, 'max_seq_length': 128})

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import seaborn as sns
import transformers
import json
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from transformers import XLNetModel, XLNetTokenizerFast
import logging
logging.basicConfig(level=logging.ERROR)
import torch
from tqdm.notebook import tqdm

from transformers import XLNetTokenizer
from torch.utils.data import TensorDataset

from transformers import BertForSequenceClassification
MAX_LEN = 512
EPOCHS = 3
LEARNING_RATE = 1e-05
tokenizer = XLNetTokenizerFast('/content/xlnet/sp10m.cased.v3.model', truncation=True)

# %%
# !pip install -qq transformers

# %%
# !pip uninstall tqdm

# %%
# !pip install tqdm==4.49.0

# %%
import transformers

from transformers import XLNetModel, XLNetTokenizer, AdamW, get_linear_schedule_with_warmup

import torch

import numpy as np

import pandas as pd

import seaborn as sns

from pylab import rcParams

import matplotlib.pyplot as plt

from matplotlib import rc

from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, classification_report

from collections import defaultdict

from textwrap import wrap

from torch import nn, optim

from torch.utils.data import Dataset, DataLoader

# %%
# !pip install pytorch-transformers

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split


from pytorch_transformers import XLNetModel, XLNetTokenizer, XLNetForSequenceClassification
from pytorch_transformers import AdamW

from tqdm import tqdm, trange
import pandas as pd
import io
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# 'Tesla V100-SXM2-16GB'

# %%
MAX_LEN = 512

# %%
from transformers import XLNetForSequenceClassification
model_name = XLNetForSequenceClassification.from_pretrained("/content/xlnet/", num_labels = 3)
# Out:
# Some weights of the model checkpoint at /content/xlnet/ were not used when initializing XLNetForSequenceClassification: ['lm_loss.bias', 'lm_loss.weight']
# - This IS expected if you are initializing XLNetForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLNetForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at /content/xlnet/ and are newly initialized: ['sequence_summary.summary.weight', 'logits_proj.weight', 'logits_proj.bias', 'sequence_summary.summary.bias']
# ...

# %%
from simpletransformers.classification import ClassificationModel
from simpletransformers.model import TransformerModel
model_args = {
    "num_train_epochs": 10,
    "learning_rate": 1e-4,
}
# Create a ClassificationModel
#model = ClassificationModel('bert', '/content/bert', num_labels=3. args = model_args)#, args={'learning_rate':1e-5, 'num_train_epochs': 3, 'reprocess_input_data': True, 'overwrite_output_dir': True)
model = TransformerModel(model_type = 'xlnet',model_name="/content/xlnet/",tokenizer_name= '/content/xlnet/sp10m.cased.v3.model', num_labels=3, args={'learning_rate':1e-5, 'num_train_epochs': 3, 'reprocess_input_data': True, 'overwrite_output_dir': True,"evaluate_during_training":True})
#model = TransformerModel('xlnet', '/content/xlnet/sp10m.cased.v3.model', num_labels=3, args={'learning_rate':1e-5, 'num_train_epochs': 3, 'reprocess_input_data': True, 'overwrite_output_dir': True})

# %%
# Create a TransformerModel with modified attributes
from simpletransformers.classification import ClassificationModel
from simpletransformers.model import TransformerModel
model = TransformerModel('xlnet', '/content/xlnet/pytorch_model.bin', num_labels=3, args={'learning_rate':1e-5, 'num_train_epochs': 2, 'reprocess_input_data': True, 'overwrite_output_dir': True})

# %%
model.train_model(train)#,overwrite_output_dir=True)
# Out:
# ...
# (849, 0.6436982144052064)

# %% [markdown]
# **berttrainfiqapost2**

# %%
test = pd.read_csv('/content/berttrainfiqapost2.tsv', sep='\t', names=['No','text','labels'])
del test['No']
test.labels +=1
test.head()
# Out:
#                                                 text  labels
# 0  Slowly adding some $FIO here but gotta be care...       2
# 1   $TRX http://stks.co/1KkK Long setup. MACD cross.       2
# 2  I am not optimistic about $amzn both fundement...       0
# 3  $GRPN might be selling off ahead of $P earning...       0
# 4  $IACI http://stks.co/tJU Looks good on the wee...       2

# %% [markdown]
# **berttrainfiqaheadline2**

# %%
test = pd.read_csv('/content/berttrainfiqaheadline2.tsv', sep='\t', names=['No','text','labels'])
del test['No']
test.labels +=1
test.head()

# %% [markdown]
# **arrangedall**

# %%
test = pd.read_csv('/content/arrangedallagree.csv' ,encoding="latin",header=None)#, names=['No','text','labels'])
test.columns = ["text",'labels']
test.labels +=1
test.head()

# %% [markdown]
# **arranged75**

# %%
test = pd.read_csv('/content/arranged75agree.csv' ,encoding="latin",header=None)#, names=['No','text','labels'])
test.columns = ["text",'labels']
test.labels +=1
test.head()

# %% [markdown]
# **arranged66**

# %%
test = pd.read_csv('/content/arranged66agree.csv' ,encoding="latin",header=None)#, names=['No','text','labels'])
test.columns = ["text",'labels']
test.labels +=1
test.head()
# Out:
#                                                 text  labels
# 0  According to Gran , the company has no plans t...       1
# 1  Technopolis plans to develop in stages an area...       1
# 2  With the new production plant the company woul...       2
# 3  According to the company 's updated strategy f...       2
# 4  For the last quarter of 2010 , Componenta 's n...       2

# %% [markdown]
# **arranged50**

# %%
test = pd.read_csv('/content/arranged50agree.csv' ,encoding="latin",header=None)#, names=['No','text','labels'])
test.columns = ["text",'labels']
#del val['No']
#val.head()

# %%
#val = val.drop(val.columns[0])
test.labels +=1
test.head()

# %%
result, model_outputs, wrong_predictions = model.eval_model(test)
# Out:
# ...
# Running Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:900: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
